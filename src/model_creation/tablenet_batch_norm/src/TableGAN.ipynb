# %%
from model.GAN import GAN
from model.generator import generator
from model.discriminator import discriminator
import model.loader as L
# Out:
# Using TensorFlow backend.

# %%
file_length = 4096
channel_num = 1
dim = 64
latent_length = 100

disc = discriminator((file_length, channel_num), dim)
gen = generator((latent_length,), (file_length, channel_num))
gan = GAN(gen, disc, latent_length)
file_loader = L.AudioFileLoader('../audio_files')
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8192)              827392
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 512)           0
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 16, 512)           0
# _________________________________________________________________
# ...

# %%
gan.fit(file_loader)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# iteration 1
# d_loss: 3528.23046875, d_diff: -0.2507776618003845, d_norm: 352.8481140136719
# iteration 2
# d_loss: 249.824462890625, d_diff: -0.3598645329475403, d_norm: 25.0184326171875
# iteration 3
# d_loss: 157.61463928222656, d_diff: -0.8369554281234741, d_norm: 15.845160484313965
# iteration 4
# d_loss: 39.20611572265625, d_diff: -1.069914698600769, d_norm: 4.0276031494140625
# iteration 5
# d_loss: 28.37441635131836, d_diff: -1.5040974617004395, d_norm: 2.98785138130188
# iteration 6
# ...

# %%
gan.generator.save('deploy_model.h5')
